# %%
import numpy as np
import numba as nb
import math
from time import perf_counter
import matplotlib.pyplot as plt
import changepoint_online as cp

from gridcp import (
    OnlineChangepointDetector,
    make_univariate_mean_change_detector,
    make_univariate_variance_change_detector,
    make_univariate_mean_or_variance_change_detector,
    make_multivariate_mean_change_detector,
    make_multivariate_mean_or_covariance_change_detector,
    make_regression_change_detector,
)
from gridcp.utils import fastlog
from gridcp.calibration import draw_samples, mc_max_statistics
from gridcp import builtins
from gridcp.builtins import gen_gaussian_regression_obs

# %% [markdown]
# # Some examples with simulations below

# %%
N = 100_000  # stream length
K_calibrate = 10  # number of MC samples for threshold calibration

detector = make_univariate_mean_change_detector()
detector.calibrate_false_alarm(
    alpha=0.05, N=N, K=K_calibrate, null_dist=np.random.normal
)

# %%
N = 50  # stream length
K_calibrate = 10000  # number of MC samples for threshold calibration
K = 1000  # number of MC samples for performance evaluation
changepoint_loc = N // 2

# %% [markdown]
# ## Univariate change-in-mean

# %%
p = 1

# %% [markdown]
# ### Known variance

# %%
detector = make_univariate_mean_change_detector()


detector.calibrate_false_alarm(
    alpha=0.05, N=N, K=K_calibrate, null_dist=np.random.normal
)
critical_value_known_var = detector._state["penalty_constant"]
print("critical value = ", critical_value_known_var)
# Out:
# critical value =  2.9627207432949887

# %%
prechange_dist = np.random.normal
postchange_dist = np.random.normal
prechange_kwargs = {"loc": 0, "scale": 1, "size": (p,)}
postchange_kwargs = {"loc": 2, "scale": 1, "size": (p,)}
xs = draw_samples(
    K=K,
    N=N,
    p=p,
    seed=123,
    pre_change_dist=prechange_dist,
    pre_change_kwargs=prechange_kwargs,
    post_change_dist=postchange_dist,
    post_change_kwargs=postchange_kwargs,
    changepoint_loc=changepoint_loc,
)

detect_times = np.ones(K, dtype=np.int64) * N
for k in range(K):
    detector = make_univariate_mean_change_detector(
        penalty_constant=critical_value_known_var
    )
    for i in range(N):
        x_new = xs[k, i]
        detector.update(x_new)
        if detector.alarm:
            detect_times[k] = i + 1
            break

print(f"Average detection delay: {np.mean(detect_times) - changepoint_loc}")
# Out:
# Average detection delay: 4.337

# %% [markdown]
# ### Uknown variance

# %%
detector = make_univariate_mean_change_detector(mode="unknown_variance")
detector.calibrate_false_alarm(
    alpha=0.05, N=N, K=K_calibrate, null_dist=np.random.normal
)
critical_value_unknown_var = detector._state["penalty_constant"]
print("critical value = ", critical_value_unknown_var)
# Out:
# critical value =  2.435296875811082

# %%
changepoint_loc = N // 2
prechange_dist = np.random.normal
postchange_dist = np.random.normal
prechange_kwargs = {"loc": 0, "scale": 1, "size": (p,)}
postchange_kwargs = {"loc": 2, "scale": 1, "size": (p,)}
xs = draw_samples(
    K=K,
    N=N,
    p=p,
    seed=123,
    pre_change_dist=prechange_dist,
    pre_change_kwargs=prechange_kwargs,
    post_change_dist=postchange_dist,
    post_change_kwargs=postchange_kwargs,
    changepoint_loc=changepoint_loc,
)

detect_times = np.ones(K, dtype=np.int64) * N
for k in range(K):
    detector = make_univariate_mean_change_detector(
        penalty_constant=critical_value_unknown_var, mode="unknown_variance"
    )
    for i in range(N):
        x_new = xs[k, i]
        detector.update(x_new)
        if detector.alarm:
            detect_times[k] = i + 1
            break

print(f"Average detection delay: {np.mean(detect_times) - changepoint_loc}")
# Out:
# Average detection delay: 5.754999999999999

# %% [markdown]
# ### Change in mean or variance

# %%
detector = make_univariate_mean_or_variance_change_detector()
detector.calibrate_false_alarm(
    alpha=0.05, N=N, K=K_calibrate, null_dist=np.random.normal
)
critical_value_meanvariance = detector._state["penalty_constant"]
print("critical value = ", critical_value_meanvariance)
# Out:
# critical value =  3.538391071737553

# %%
changepoint_loc = N // 2
prechange_dist = np.random.normal
postchange_dist = np.random.normal
prechange_kwargs = {"loc": 0, "scale": 1, "size": (p,)}
postchange_kwargs = {"loc": 2, "scale": 1, "size": (p,)}
xs = draw_samples(
    K=K,
    N=N,
    p=p,
    seed=123,
    pre_change_dist=prechange_dist,
    pre_change_kwargs=prechange_kwargs,
    post_change_dist=postchange_dist,
    post_change_kwargs=postchange_kwargs,
    changepoint_loc=changepoint_loc,
)

detect_times = np.ones(K, dtype=np.int64) * N
for k in range(K):
    detector = make_univariate_mean_or_variance_change_detector(
        penalty_constant=critical_value_meanvariance
    )
    for i in range(N):
        x_new = xs[k, i]
        detector.update(x_new)
        if detector.alarm:
            detect_times[k] = i + 1
            break

print(f"Average detection time: {np.mean(detect_times) - changepoint_loc}")
# Out:
# Average detection time: 10.468000000000004

# %%
mus = np.linspace(0, 3, 10)

changepoint_loc = N // 2
prechange_dist = np.random.normal
postchange_dist = np.random.normal

dd1 = np.ones((len(mus), K)) * N
dd2 = np.ones((len(mus), K)) * N
dd3 = np.ones((len(mus), K)) * N


for j in range(len(mus)):
    prechange_kwargs = {"loc": 0, "scale": 1, "size": (p,)}
    postchange_kwargs = {"loc": mus[j], "scale": 1, "size": (p,)}
    xs = draw_samples(
        K=K,
        N=N,
        p=p,
        seed=1234,
        pre_change_dist=prechange_dist,
        pre_change_kwargs=prechange_kwargs,
        post_change_dist=postchange_dist,
        post_change_kwargs=postchange_kwargs,
        changepoint_loc=changepoint_loc,
    )

    for k in range(K):
        detector1 = make_univariate_mean_change_detector(
            penalty_constant=critical_value_known_var
        )
        detector2 = make_univariate_mean_change_detector(
            penalty_constant=critical_value_unknown_var,
            mode="unknown_variance",
        )
        detector3 = make_univariate_mean_or_variance_change_detector(
            penalty_constant=critical_value_meanvariance
        )
        for i in range(N):
            x_new = xs[k, i]
            detector1.update(x_new)
            if detector1.alarm:
                dd1[j, k] = i + 1
                break
        for i in range(N):
            x_new = xs[k, i]
            detector2.update(x_new)
            if detector2.alarm:
                dd2[j, k] = i + 1
                break
        for i in range(N):
            x_new = xs[k, i]
            detector3.update(x_new)
            if detector3.alarm:
                dd3[j, k] = i + 1
                break

# %%
print("FA 1:", np.mean(dd1[0] < N))
print("FA 2:", np.mean(dd2[0] < N))
print("FA 3:", np.mean(dd3[0] < N))
# Out:
# FA 1: 0.049
# FA 2: 0.054
# FA 3: 0.052

# %%
avg_dd1 = np.mean(dd1, axis=1) - changepoint_loc
avg_dd2 = np.mean(dd2, axis=1) - changepoint_loc
avg_dd3 = np.mean(dd3, axis=1) - changepoint_loc

plt.plot(mus, avg_dd1, label="mean change detector")
plt.plot(mus, avg_dd2, label="mean change detector unknown variance")
plt.plot(mus, avg_dd3, label="mean and variance change detector")
plt.xlabel("mean change magnitude")
plt.ylabel("average detection delay")
plt.legend()
plt.show()

# %% [markdown]
# ## Univariate change in variance

# %% [markdown]
# ### Known mean

# %%
detector = make_univariate_variance_change_detector()
detector.calibrate_false_alarm(
    alpha=0.05, N=N, K=K_calibrate, null_dist=np.random.normal
)
critical_value_known_mean = detector._state["penalty_constant"]

# %%
changepoint_loc = N // 2
prechange_dist = np.random.normal
postchange_dist = np.random.normal
prechange_kwargs = {"loc": 0, "scale": 1, "size": (p,)}
postchange_kwargs = {"loc": 0, "scale": 4, "size": (p,)}
xs = draw_samples(
    K=K,
    N=N,
    p=p,
    seed=123,
    pre_change_dist=prechange_dist,
    pre_change_kwargs=prechange_kwargs,
    post_change_dist=postchange_dist,
    post_change_kwargs=postchange_kwargs,
    changepoint_loc=changepoint_loc,
)

detect_times = np.ones(K, dtype=np.int64) * N
for k in range(K):
    detector = make_univariate_variance_change_detector(
        penalty_constant=critical_value_known_mean
    )
    for i in range(N):
        x_new = xs[k, i]
        detector.update(x_new)
        if detector.alarm:
            detect_times[k] = i + 1
            break

print(f"Average detection time: {np.mean(detect_times) - changepoint_loc}")
# Out:
# Average detection time: 4.882999999999999

# %%
K = 1000
postchangesds = np.linspace(1, 5, 10)


changepoint_loc = N // 2
prechange_dist = np.random.normal
postchange_dist = np.random.normal

dd1 = np.ones((len(postchangesds), K)) * N
dd2 = np.ones((len(postchangesds), K)) * N


for j in range(len(postchangesds)):
    prechange_kwargs = {"loc": 0, "scale": 1, "size": (p,)}
    postchange_kwargs = {"loc": 0, "scale": postchangesds[j], "size": (p,)}
    xs = draw_samples(
        K=K,
        N=N,
        p=p,
        seed=1234,
        pre_change_dist=prechange_dist,
        pre_change_kwargs=prechange_kwargs,
        post_change_dist=postchange_dist,
        post_change_kwargs=postchange_kwargs,
        changepoint_loc=changepoint_loc,
    )

    for k in range(K):
        detector1 = make_univariate_variance_change_detector(
            penalty_constant=critical_value_known_mean
        )
        detector2 = make_univariate_mean_or_variance_change_detector(
            penalty_constant=critical_value_meanvariance
        )
        for i in range(N):
            x_new = xs[k, i]
            detector1.update(x_new)
            if detector1.alarm:
                dd1[j, k] = i + 1
                break
        for i in range(N):
            x_new = xs[k, i]
            detector2.update(x_new)
            if detector2.alarm:
                dd2[j, k] = i + 1
                break

# %%
print("FA 1:", np.mean(dd1[0] < N))
print("FA 2:", np.mean(dd2[0] < N))
# Out:
# FA 1: 0.054
# FA 2: 0.052

# %%
avg_dd1 = np.mean(dd1, axis=1) - changepoint_loc
avg_dd2 = np.mean(dd2, axis=1) - changepoint_loc

plt.plot(postchangesds, avg_dd1, label="variance change detector known mean")
plt.plot(postchangesds, avg_dd2, label="mean and variance change detector")
plt.xlabel("post-change standard deviation")
plt.ylabel("average detection delay")
plt.legend()
plt.show()

# %% [markdown]
# ## Multivariate change in mean

# %%
p = 10
N = 50  # stream length
K_calibrate = 10000  # number of MC samples for threshold calibration
K = 1000  # number of MC samples for performance evaluation
changepoint_loc = N // 2

# %% [markdown]
# ### Known variance (identity)

# %%
detector = make_multivariate_mean_change_detector(p=p)
detector.calibrate_false_alarm(
    alpha=0.05,
    N=N,
    K=K_calibrate,
    null_dist=np.random.normal,
    null_kwargs={"loc": 0, "scale": 1, "size": (p,)},
)
critical_value_multivariate_known_var = detector._state["penalty_constant"]
print("critical value = ", critical_value_multivariate_known_var)
# Out:
# critical value =  3.2426766089345445

# %%
prechange_dist = np.random.normal
postchange_dist = np.random.normal
prechange_kwargs = {"loc": 0, "scale": 1, "size": (p,)}
postchange_kwargs = {"loc": 3 / math.sqrt(p), "scale": 1, "size": (p,)}
xs = draw_samples(
    K=K,
    N=N,
    p=p,
    seed=123,
    pre_change_dist=prechange_dist,
    pre_change_kwargs=prechange_kwargs,
    post_change_dist=postchange_dist,
    post_change_kwargs=postchange_kwargs,
    changepoint_loc=changepoint_loc,
)

detect_times = np.ones(K, dtype=np.int64) * N
for k in range(K):
    detector = make_multivariate_mean_change_detector(
        p=p, penalty_constant=critical_value_multivariate_known_var
    )
    for i in range(N):
        x_new = xs[k, i]
        detector.update(x_new)
        if detector.alarm:
            detect_times[k] = i + 1
            break

print(f"Average detection delay: {np.mean(detect_times) - changepoint_loc}")
# Out:
# Average detection delay: 2.8810000000000002

# %% [markdown]
# ### Uknown variance

# %%
detector = make_multivariate_mean_change_detector(p=p, mode="unknown_variance")
detector.calibrate_false_alarm(
    alpha=0.05,
    N=N,
    K=K_calibrate,
    null_dist=np.random.normal,
    null_kwargs={"loc": 0, "scale": 1, "size": (p,)},
)
critical_value_multivariate_unknown_var = detector._state["penalty_constant"]
print("critical value = ", critical_value_multivariate_unknown_var)
# Out:
# critical value =  2.5163534066256585

# %%
prechange_dist = np.random.normal
postchange_dist = np.random.normal
prechange_kwargs = {"loc": 0, "scale": 1, "size": (p,)}
postchange_kwargs = {"loc": 3 / math.sqrt(p), "scale": 1, "size": (p,)}
xs = draw_samples(
    K=K,
    N=N,
    p=p,
    seed=123,
    pre_change_dist=prechange_dist,
    pre_change_kwargs=prechange_kwargs,
    post_change_dist=postchange_dist,
    post_change_kwargs=postchange_kwargs,
    changepoint_loc=changepoint_loc,
)

detect_times = np.ones(K, dtype=np.int64) * N
for k in range(K):
    detector = make_multivariate_mean_change_detector(
        p=p,
        penalty_constant=critical_value_multivariate_unknown_var,
        mode="unknown_variance",
    )
    for i in range(N):
        x_new = xs[k, i]
        detector.update(x_new)
        if detector.alarm:
            detect_times[k] = i + 1
            break

print(f"Average detection delay: {np.mean(detect_times) - changepoint_loc}")
# Out:
# Average detection delay: 8.354999999999997

# %% [markdown]
# ### Change in mean or variance

# %%
detector = make_multivariate_mean_or_covariance_change_detector(p=p)
detector.calibrate_false_alarm(
    alpha=0.05,
    N=N,
    K=K_calibrate,
    null_dist=np.random.normal,
    null_kwargs={"loc": 0, "scale": 1, "size": (p,)},
)
critical_value_multivariate_meanvariance = detector._state["penalty_constant"]
print("critical value = ", critical_value_meanvariance)
# Out:
# critical value =  3.538391071737553

# %%
prechange_dist = np.random.normal
postchange_dist = np.random.normal
prechange_kwargs = {"loc": 0, "scale": 1, "size": (p,)}
postchange_kwargs = {"loc": 3 / math.sqrt(p), "scale": 1, "size": (p,)}
xs = draw_samples(
    K=K,
    N=N,
    p=p,
    seed=123,
    pre_change_dist=prechange_dist,
    pre_change_kwargs=prechange_kwargs,
    post_change_dist=postchange_dist,
    post_change_kwargs=postchange_kwargs,
    changepoint_loc=changepoint_loc,
)

detect_times = np.ones(K, dtype=np.int64) * N
for k in range(K):
    detector = make_multivariate_mean_or_covariance_change_detector(
        p=p, penalty_constant=critical_value_multivariate_meanvariance
    )
    for i in range(N):
        x_new = xs[k, i]
        detector.update(x_new)
        if detector.alarm:
            detect_times[k] = i + 1
            break

print(f"Average detection time: {np.mean(detect_times) - changepoint_loc}")
# Out:
# Average detection time: 21.247999999999998

# %%
phis = np.linspace(0, 6, 10)

changepoint_loc = N // 2
prechange_dist = np.random.normal
postchange_dist = np.random.normal

dd1 = np.ones((len(phis), K)) * N
dd2 = np.ones((len(phis), K)) * N
dd3 = np.ones((len(phis), K)) * N


for j in range(len(phis)):
    prechange_kwargs = {"loc": 0, "scale": 1, "size": (p,)}
    postchange_kwargs = {"loc": phis[j] / math.sqrt(p), "scale": 1, "size": (p,)}
    xs = draw_samples(
        K=K,
        N=N,
        p=p,
        seed=1234,
        pre_change_dist=prechange_dist,
        pre_change_kwargs=prechange_kwargs,
        post_change_dist=postchange_dist,
        post_change_kwargs=postchange_kwargs,
        changepoint_loc=changepoint_loc,
    )

    for k in range(K):
        detector1 = make_multivariate_mean_change_detector(
            p=p, penalty_constant=critical_value_multivariate_known_var
        )
        detector2 = make_multivariate_mean_change_detector(
            p=p,
            penalty_constant=critical_value_multivariate_unknown_var,
            mode="unknown_variance",
        )
        detector3 = make_multivariate_mean_or_covariance_change_detector(
            p=p, penalty_constant=critical_value_multivariate_meanvariance
        )
        for i in range(N):
            x_new = xs[k, i]
            detector1.update(x_new)
            if detector1.alarm:
                dd1[j, k] = i + 1
                break
        for i in range(N):
            x_new = xs[k, i]
            detector2.update(x_new)
            if detector2.alarm:
                dd2[j, k] = i + 1
                break
        for i in range(N):
            x_new = xs[k, i]
            detector3.update(x_new)
            if detector3.alarm:
                dd3[j, k] = i + 1
                break

# %%
print("FA 1:", np.mean(dd1[0] < N))
print("FA 2:", np.mean(dd2[0] < N))
print("FA 3:", np.mean(dd3[0] < N))
# Out:
# FA 1: 0.055
# FA 2: 0.039
# FA 3: 0.052

# %%
avg_dd1 = np.mean(dd1, axis=1) - changepoint_loc
avg_dd2 = np.mean(dd2, axis=1) - changepoint_loc
avg_dd3 = np.mean(dd3, axis=1) - changepoint_loc

plt.plot(phis, avg_dd1, label="mean change detector")
plt.plot(phis, avg_dd2, label="mean change detector unknown covariance")
plt.plot(phis, avg_dd3, label="mean and variance change detector")
plt.xlabel("mean change magnitude")
plt.ylabel("average detection delay")
plt.legend()
plt.show()

# %% [markdown]
# # Change in regression coefficients

# %% [markdown]
# ### McScan

# %%
N = 200
q = 10
K_calibrate = 1000
K = 1000
beta0 = np.random.normal(loc=0, scale=1, size=(q,))

detector = make_regression_change_detector(q=q)
detector.calibrate_false_alarm(
    alpha=0.05,
    N=N,
    K=K_calibrate,
    null_dist=gen_gaussian_regression_obs,
    null_kwargs={"beta0": beta0},
)
critical_value_reg = detector._state["penalty_constant"]
print("critical value = ", critical_value_reg)
# Out:
# critical value =  11.955805843341558

# %% [markdown]
# ### Direct

# %%
N = 200
q = 10
K_calibrate = 1000
K = 1000
beta0 = np.random.normal(loc=0, scale=1, size=(q,))

detector = make_regression_change_detector(q=q, mode="direct")
detector.calibrate_false_alarm(
    alpha=0.05,
    N=N,
    K=K_calibrate,
    null_dist=gen_gaussian_regression_obs,
    null_kwargs={"beta0": beta0},
)
critical_value_reg_direct = detector._state["penalty_constant"]
print("critical value = ", critical_value_reg_direct)
# Out:
# critical value =  46.80811930977104

# %%
rhos = np.linspace(0, 30, 10)
s = q
K = 100
changepoint_loc = N // 2
prechange_dist = gen_gaussian_regression_obs
postchange_dist = gen_gaussian_regression_obs

dd1 = np.ones((len(rhos), K)) * N
dd2 = np.ones((len(rhos), K)) * N


for j in range(len(rhos)):
    prechange_kwargs = {"beta0": beta0}
    postchange_kwargs = {
        "beta0": beta0,
        "add_perturbation": True,
        "rho": rhos[j],
        "s": s,
    }
    xs = draw_samples(
        K=K,
        N=N,
        p=q + 1,
        seed=1234,
        pre_change_dist=prechange_dist,
        pre_change_kwargs=prechange_kwargs,
        post_change_dist=postchange_dist,
        post_change_kwargs=postchange_kwargs,
        changepoint_loc=changepoint_loc,
    )

    for k in range(K):
        detector1 = make_regression_change_detector(
            q=q, penalty_constant=critical_value_reg
        )
        detector2 = make_regression_change_detector(
            q=q, penalty_constant=critical_value_reg_direct, mode="direct"
        )

        for i in range(N):
            x_new = xs[k, i]
            detector1.update(x_new)
            if detector1.alarm:
                dd1[j, k] = i + 1
                break
        for i in range(N):
            x_new = xs[k, i]
            detector2.update(x_new)
            if detector2.alarm:
                dd2[j, k] = i + 1
                break

# %%
avg_dd1 = np.mean(dd1, axis=1) - changepoint_loc
avg_dd2 = np.mean(dd2, axis=1) - changepoint_loc


plt.plot(rhos, avg_dd1, label="regression change detector")
plt.plot(rhos, avg_dd2, label="regression change detector (direct mode)")
plt.xlabel("rho parameter controlling change magnitude")
plt.ylabel("average detection delay")
plt.legend()
plt.show()

# %% [markdown]
# ### Make your own detector

# %%
@nb.njit(cache=True)
def change_univariate_simple_f(sum_pre, sum_post, pos, t, q=2):
    g = t - pos
    n1 = pos
    n2 = g

    mean_pre = sum_pre / n1
    mean_post = sum_post / n2
    out_stat = (mean_pre - mean_post) ** q
    return np.sum(out_stat)

@nb.njit(cache=True)
def change_univariate_simple_h(x):
    return x

@nb.njit(cache=False)
def _scalar_max_ll(ki, n_i):
    if ki <= 0 or ki >= n_i:
        return 0.0
    p_hat = ki / n_i
    return ki * np.log(p_hat) + (n_i - ki) * np.log1p(-p_hat)

@nb.njit(cache=True)
def bernoulli_max_ll(k, n):
    # k successes in n trials; returns max log-likelihood under Bernoulli
    # (i.e. with p = k/n). For k=0 or k=n this is 0. Supports scalar k
    # or 1D arrays of ks.

    out = np.empty(k.shape, dtype=np.float64)
    for i in range(k.shape[0]):
        out[i] = _scalar_max_ll(k[i], n)
    return out

@nb.njit(cache=True)
def change_univariate_simple_penalty(pos, t, p):
    logg = fastlog(t)
    logg = logg + math.sqrt(logg)
    return logg

@nb.njit(cache=False)
def change_bernoulli_f(sum_pre, sum_post, pos, t):
    # Use the exact Bernoulli maximum log-likelihood values.
    # For k=0 or k=n, the max log-likelihood is 0 (log(1)=0), so this is a
    # well-defined finite value and avoids any log(0) issues.

    g = t - pos
    if pos <= 0 or g <= 0:
        return 0.0

    ll_post = bernoulli_max_ll(sum_post, g)
    ll_pre = bernoulli_max_ll(sum_pre, pos)
    ll_tot = bernoulli_max_ll(sum_pre + sum_post, t)
    out = 2.0 * (ll_post + ll_pre - ll_tot)
    # If `out` is scalar, return directly; if it's array, sum over entries.
    return np.sum(out)

@nb.njit(cache=False)
def change_bernoulli_h(x, grid=np.arange(-5, 5, 0.25)):
    return np.array([x[0] <= p for p in grid], dtype=np.float64)

@nb.njit(cache=False)
def change_bernoulli_penalty(pos, t, p):
    return 1

# %%
detector = OnlineChangepointDetector(
    p=1, f=change_bernoulli_f, h=change_bernoulli_h, penalty=change_bernoulli_penalty, penalty_constant=10
)

N = 1000  # stream length
K_calibrate = 1000  # number of MC samples for threshold calibration
detector.calibrate_false_alarm(
    alpha=0.05, N=N, K=K_calibrate, null_dist=np.random.normal,
)
critical_value_known_var = detector._state["penalty_constant"]
print("critical value = ", critical_value_known_var)
# Out:
# critical value =  153.48229973164672

# %%
# Test Bernoulli detector on synthetic Gaussian change-in-mean data
np.random.seed(42)
N_test = 1000
changepoint = N_test // 3

# Generate synthetic Gaussian data with known changepoint
X_gaussian = np.concatenate([
    np.random.normal(0, 1, changepoint),      # Pre-change: N(0,1)
    np.random.normal(2, 1, N_test - changepoint)  # Post-change: N(2,1)
])

# Initialize detector with the calibrated critical value
detector_bernoulli = OnlineChangepointDetector(
    p=1, 
    f=change_bernoulli_f, 
    h=change_bernoulli_h, 
    penalty=change_bernoulli_penalty, 
    penalty_constant=critical_value_known_var
)

# Run detector and track statistics
maxx_values = []
alarm_time_bernoulli = None

for i in range(N_test):
    x_new = np.array([X_gaussian[i]])
    detector_bernoulli.update(x_new)
    maxx_values.append(detector_bernoulli._state["maxx"])
    
    if detector_bernoulli.alarm and alarm_time_bernoulli is None:
        alarm_time_bernoulli = i + 1

# Calculate detection delay
if alarm_time_bernoulli is not None:
    detection_delay = alarm_time_bernoulli - changepoint - 1
    print(f"Alarm triggered at time: {alarm_time_bernoulli}")
    print(f"True changepoint: {changepoint + 1}")
    print(f"Detection delay: {detection_delay}")
else:
    print("No alarm triggered")
    detection_delay = None

# Plot results
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12, 8))

# Plot 1: Data with true and detected changepoint
ax1.plot(X_gaussian, linewidth=0.8, label='Data')
ax1.axvline(changepoint, color='green', linestyle='--', linewidth=2, label=f'True changepoint (t={changepoint+1})')
if alarm_time_bernoulli is not None:
    ax1.axvline(alarm_time_bernoulli - 1, color='red', linestyle='--', linewidth=2, label=f'Detected changepoint (t={alarm_time_bernoulli})')
ax1.set_xlabel('Time')
ax1.set_ylabel('Value')
ax1.set_title('Synthetic Gaussian Data: Change in Mean from 0 to 2')
ax1.legend()
ax1.grid(True, alpha=0.3)

# Plot 2: Detector statistic vs. threshold
ax2.plot(maxx_values, linewidth=1, label='Detector Statistic (GLR)')
ax2.axhline(critical_value_known_var, color='red', linestyle='--', linewidth=2, label=f'Threshold (critical value = {critical_value_known_var:.2f})')
ax2.axvline(changepoint, color='green', linestyle='--', linewidth=1, alpha=0.5, label='True changepoint')
if alarm_time_bernoulli is not None:
    ax2.axvline(alarm_time_bernoulli - 1, color='orange', linestyle='--', linewidth=1, alpha=0.5, label='Detection')
ax2.set_xlabel('Time')
ax2.set_ylabel('Statistic Value')
ax2.set_title('Bernoulli Detector GLR Statistic over Time')
ax2.legend()
ax2.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

print(f"\nBernoulli detector results on Gaussian change-in-mean data:")
print(f"  Stream length: {N_test}")
print(f"  Change magnitude: 2.0")
print(f"  Critical value: {critical_value_known_var:.4f}")
# Out:
# Alarm triggered at time: 339
# True changepoint: 334
# Detection delay: 5
# Bernoulli detector results on Gaussian change-in-mean data:
#   Stream length: 1000
#   Change magnitude: 2.0
#   Critical value: 153.4823

# %%
# Test Bernoulli detector on variance change data
np.random.seed(42)
N_test_var = 1000
changepoint_var = N_test_var // 2

# Generate synthetic data with variance change (mean stays at 0)
# Pre-change: N(0, 1), Post-change: N(0, 3)
X_variance = np.concatenate([
    np.random.normal(0, 1, changepoint_var),              # Pre-change: variance = 1
    np.random.normal(0, np.sqrt(3), N_test_var - changepoint_var)  # Post-change: variance = 3
])

# Initialize detector with the calibrated critical value
detector_bernoulli_var = OnlineChangepointDetector(
    p=1, 
    f=change_bernoulli_f, 
    h=change_bernoulli_h, 
    penalty=change_bernoulli_penalty, 
    penalty_constant=critical_value_known_var
)

# Run detector and track statistics
maxx_values_var = []
alarm_time_var = None

for i in range(N_test_var):
    x_new = np.array([X_variance[i]])
    detector_bernoulli_var.update(x_new)
    maxx_values_var.append(detector_bernoulli_var._state["maxx"])
    
    if detector_bernoulli_var.alarm and alarm_time_var is None:
        alarm_time_var = i + 1

# Calculate detection delay
if alarm_time_var is not None:
    detection_delay_var = alarm_time_var - changepoint_var - 1
    print(f"Bernoulli detector on variance change (1→3):")
    print(f"  Alarm triggered at time: {alarm_time_var}")
    print(f"  True changepoint: {changepoint_var + 1}")
    print(f"  Detection delay: {detection_delay_var}")
else:
    print("Bernoulli detector on variance change: No alarm triggered")
    detection_delay_var = None

# Plot results
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12, 8))

# Plot 1: Data with true and detected changepoint
ax1.plot(X_variance, linewidth=0.8, label='Data', alpha=0.7)
ax1.axvline(changepoint_var, color='green', linestyle='--', linewidth=2, 
            label=f'True changepoint (t={changepoint_var+1})')
if alarm_time_var is not None:
    ax1.axvline(alarm_time_var - 1, color='red', linestyle='--', linewidth=2, 
                label=f'Detected changepoint (t={alarm_time_var})')
ax1.set_xlabel('Time')
ax1.set_ylabel('Value')
ax1.set_title('Synthetic Data: Change in Variance from 1 to 3 (mean = 0)')
ax1.legend()
ax1.grid(True, alpha=0.3)

# Plot 2: Detector statistic vs. threshold
ax2.plot(maxx_values_var, linewidth=1, label='Detector Statistic (GLR)')
ax2.axhline(critical_value_known_var, color='red', linestyle='--', linewidth=2, 
            label=f'Threshold (critical value = {critical_value_known_var:.2f})')
ax2.axvline(changepoint_var, color='green', linestyle='--', linewidth=1, alpha=0.5, 
            label='True changepoint')
if alarm_time_var is not None:
    ax2.axvline(alarm_time_var - 1, color='orange', linestyle='--', linewidth=1, 
                alpha=0.5, label='Detection')
ax2.set_xlabel('Time')
ax2.set_ylabel('Statistic Value')
ax2.set_title('Bernoulli Detector GLR Statistic over Variance Change')
ax2.legend()
ax2.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()
# Out:
# Bernoulli detector on variance change (1→3):
#   Alarm triggered at time: 534
#   True changepoint: 501
#   Detection delay: 33

# %% [markdown]
# ## Comparison with NPFocus detector from changepoint-online

# %%
# --- Change in mean: Bernoulli vs NPFocus runtime comparison ---
import time

N_series = 1000
N_test = 100
changepoint = N_test // 2
mu_pre = 0.0
mu_post = 2.0
var = 1.0

bernoulli_delays_mean = np.zeros(N_series)
npfocus_delays_mean = np.zeros(N_series)
bernoulli_times_mean = np.zeros(N_series)
npfocus_times_mean = np.zeros(N_series)

# Calibrate threshold for NPFocus (mean change)
alpha = 0.05
N_calibrate = 1000
npfocus_stats_mean = np.zeros(N_calibrate)
for k in range(N_calibrate):
    detector_np = cp.NPFocus(np.arange(-5, 5, 0.25))
    X_cal = np.random.normal(mu_pre, np.sqrt(var), N_test)
    max_stat = -np.inf
    for i in range(N_test):
        detector_np.update(X_cal[i])
        stat = np.sum(detector_np.statistic())
        if stat > max_stat:
            max_stat = stat
    npfocus_stats_mean[k] = max_stat
threshold_np_mean = np.percentile(npfocus_stats_mean, 100 * (1 - alpha))

for k in range(N_series):
    X = np.concatenate([
        np.random.normal(mu_pre, np.sqrt(var), changepoint),
        np.random.normal(mu_post, np.sqrt(var), N_test - changepoint)
    ])

    # Bernoulli detector (as in your code)
    start_time = time.perf_counter()
    detector_bern = OnlineChangepointDetector(
        p=1,
        f=change_bernoulli_f,
        h=change_bernoulli_h,
        penalty=change_bernoulli_penalty,
        penalty_constant=critical_value_known_var
    )
    alarm_bern = None
    for i in range(N_test):
        x_new = np.array([X[i]])
        detector_bern.update(x_new)
        if detector_bern.alarm and alarm_bern is None:
            alarm_bern = i + 1
            break
    bernoulli_times_mean[k] = time.perf_counter() - start_time
    bernoulli_delays_mean[k] = max(alarm_bern - changepoint, 0) if alarm_bern else N_test - changepoint

    # NPFocus detector
    start_time = time.perf_counter()
    detector_np = cp.NPFocus(np.arange(-5, 5, 0.25))
    alarm_np = None
    for i in range(N_test):
        detector_np.update(X[i])
        if np.sum(detector_np.statistic()) > threshold_np_mean and alarm_np is None:
            alarm_np = i + 1
            break
    npfocus_times_mean[k] = time.perf_counter() - start_time
    npfocus_delays_mean[k] = max(alarm_np - changepoint, 0) if alarm_np else N_test - changepoint

# --- Results ---
print("Bernoulli detector (mean change):")
print(f"  Average detection delay: {np.mean(bernoulli_delays_mean):.2f} samples")
print(f"  Average runtime: {np.mean(bernoulli_times_mean)*1000:.3f} ms")
print(f"  Early detection rate: {np.mean(bernoulli_delays_mean < 0):.4f}")
print(f"  Missed detections: {np.sum(bernoulli_delays_mean == N_test - changepoint):d}")

print("\nNPFocus detector (mean change):")
print(f"  Average detection delay: {np.mean(npfocus_delays_mean):.2f} samples")
print(f"  Average runtime: {np.mean(npfocus_times_mean)*1000:.3f} ms")
print(f"  Early detection rate: {np.mean(npfocus_delays_mean < 0):.4f}")
print(f"  Missed detections: {np.sum(npfocus_delays_mean == N_test - changepoint):d}")

print(f"\nSpeedup: NPFocus is {np.mean(npfocus_times_mean)/np.mean(bernoulli_times_mean):.1f}x slower than Bernoulli detector (mean change)")

# --- Plots: Detection delay and runtime histograms ---
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

# Detection delay histogram
bins_delay = np.arange(-changepoint-5, N_test-changepoint+5, 2)
ax1.hist(bernoulli_delays_mean, bins=bins_delay, alpha=0.6, label='Bernoulli', color='red', edgecolor='black')
ax1.hist(npfocus_delays_mean, bins=bins_delay, alpha=0.6, label='NPFocus', color='blue', edgecolor='black')
ax1.set_xlabel('Detection Delay (samples)')
ax1.set_ylabel('Count')
ax1.set_title('Detection Delay Distribution (Mean Change)')
ax1.legend()
ax1.grid(True, alpha=0.3)

# Runtime histogram
bins_runtime = np.linspace(0, max(np.max(bernoulli_times_mean), np.max(npfocus_times_mean)), 30)
ax2.hist(bernoulli_times_mean*1000, bins=bins_runtime*1000, alpha=0.6, label='Bernoulli', color='red', edgecolor='black')
ax2.hist(npfocus_times_mean*1000, bins=bins_runtime*1000, alpha=0.6, label='NPFocus', color='blue', edgecolor='black')
ax2.set_xlabel('Runtime per Series (ms)')
ax2.set_ylabel('Count')
ax2.set_title('Runtime Distribution (Mean Change)')
ax2.legend()
ax2.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()
# Out:
# Bernoulli detector (mean change):
#   Average detection delay: 6.89 samples
#   Average runtime: 2.236 ms
#   Early detection rate: 0.0000
#   Missed detections: 0
#
# NPFocus detector (mean change):
#   Average detection delay: 4.62 samples
#   Average runtime: 48.151 ms
#   Early detection rate: 0.0000
#   Missed detections: 0
#
# Speedup: NPFocus is 21.5x slower than Bernoulli detector (mean change)

# %%
# Large-scale comparison: 1000 series with variance change (1→3)
import time

N_series = 100
N_test = 1000
changepoint = N_test // 2
var_pre = 1.0
var_post = 3.0

# Storage for results
bernoulli_delays = np.zeros(N_series)
npfocus_delays = np.zeros(N_series)
bernoulli_times = np.zeros(N_series)
npfocus_times = np.zeros(N_series)

# Calibrate NPFocus threshold for variance change detection

alpha = 0.05
N_calibrate = 1000
NPFcocus_calibrate_stats = np.zeros(N_calibrate)
for k in range(N_calibrate):
    print((k+1)/N_calibrate)
    detector_np = cp.NPFocus(np.arange(-5, 5, 0.25))
    X_calibrate = np.random.normal(0, np.sqrt(var_pre), N_test)
    max_stat = -np.inf
    for i in range(N_test):
        detector_np.update(X_calibrate[i])
        stat = np.sum(detector_np.statistic())
        if stat > max_stat:
            max_stat = stat
    NPFcocus_calibrate_stats[k] = max_stat

threshold_np = np.percentile(NPFcocus_calibrate_stats, 100 * (1 - alpha))
print("NPFocus calibrated threshold for variance change detection:", threshold_np)

for k in range(N_series):
    # Generate data
    X = np.concatenate([
        np.random.normal(0, np.sqrt(var_pre), changepoint),
        np.random.normal(0, np.sqrt(var_post), N_test - changepoint)
    ])

    # Bernoulli detector
    start_time = time.perf_counter()
    detector_bern = OnlineChangepointDetector(
        p=1,
        f=change_bernoulli_f,
        h=change_bernoulli_h,
        penalty=change_bernoulli_penalty,
        penalty_constant=critical_value_known_var
    )
    alarm_bern = None
    for i in range(N_test):
        x_new = np.array([X[i]])
        detector_bern.update(x_new)
        if detector_bern.alarm and alarm_bern is None:
            alarm_bern = i + 1
    bernoulli_times[k] = time.perf_counter() - start_time
    bernoulli_delays[k] = (alarm_bern - changepoint - 1) if alarm_bern else N_test - changepoint

    # NPFocus detector
    start_time = time.perf_counter()
    detector_np = cp.NPFocus(np.arange(-5, 5, 0.25))
    alarm_np = None
    for i in range(N_test):
        detector_np.update(X[i])
        if np.sum(detector_np.statistic()) > threshold_np and alarm_np is None:
            alarm_np = i + 1
    npfocus_times[k] = time.perf_counter() - start_time
    npfocus_delays[k] = (alarm_np - changepoint - 1) if alarm_np else N_test - changepoint

# Results
print("Large-scale comparison (1000 series, variance change 1→3):")
print(f"Bernoulli detector:")
print(f"  Average detection delay: {np.mean(bernoulli_delays):.2f} samples")
print(f"  Average runtime: {np.mean(bernoulli_times)*1000:.3f} ms")
print(f"  False alarm rate: {np.mean(bernoulli_delays < 0):.4f}")
print(f"  Missed detections: {np.sum(bernoulli_delays == N_test - changepoint):d}")

print(f"\nNPFocus detector:")
print(f"  Average detection delay: {np.mean(npfocus_delays):.2f} samples")
print(f"  Average runtime: {np.mean(npfocus_times)*1000:.3f} ms")
print(f"  False alarm rate: {np.mean(npfocus_delays < 0):.4f}")
print(f"  Missed detections: {np.sum(npfocus_delays == N_test - changepoint):d}")

print(f"\nSpeedup: NPFocus is {np.mean(npfocus_times)/np.mean(bernoulli_times):.1f}x slower than Bernoulli detector")

# Plot detection delay distributions
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))

ax1.hist(bernoulli_delays, bins=50, alpha=0.7, label='Bernoulli', density=True)
ax1.hist(npfocus_delays, bins=50, alpha=0.7, label='NPFocus', density=True)
ax1.set_xlabel('Detection Delay (samples)')
ax1.set_ylabel('Density')
ax1.set_title('Detection Delay Distributions')
ax1.legend()
ax1.grid(True, alpha=0.3)

ax2.hist(bernoulli_times*1000, bins=50, alpha=0.7, label='Bernoulli')
ax2.hist(npfocus_times*1000, bins=50, alpha=0.7, label='NPFocus')
ax2.set_xlabel('Runtime (ms)')
ax2.set_ylabel('Count')
ax2.set_title('Runtime Distributions')
ax2.legend()
ax2.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()
# Out:
# 0.001
# 0.002
# 0.003
# 0.004
# 0.005
# 0.006
# 0.007
# 0.008
# 0.009
# 0.01
# 0.011
# 0.012
# 0.013
# 0.014
# 0.015
# 0.016
# 0.017
# 0.018
# 0.019
# 0.02
# 0.021
# 0.022
# 0.023
# 0.024
# 0.025
# 0.026
# 0.027
# 0.028
# 0.029
# 0.03
# 0.031
# 0.032
# 0.033
# 0.034
# 0.035
# 0.036
# 0.037
# 0.038
# 0.039
# 0.04
# 0.041
# 0.042
# 0.043
# 0.044
# 0.045
# 0.046
# 0.047
# 0.048
# 0.049
# 0.05
# 0.051
# 0.052
# 0.053
# 0.054
# 0.055
# 0.056
# 0.057
# 0.058
# 0.059
# 0.06
# 0.061
# 0.062
# 0.063
# 0.064
# 0.065
# 0.066
# 0.067
# 0.068
# 0.069
# 0.07
# 0.071
# 0.072
# 0.073
# 0.074
# 0.075
# 0.076
# 0.077
# 0.078
# 0.079
# 0.08
# 0.081
# 0.082
# 0.083
# 0.084
# 0.085
# 0.086
# 0.087
# 0.088
# 0.089
# 0.09
# 0.091
# 0.092
# 0.093
# 0.094
# 0.095
# 0.096
# 0.097
# 0.098
# 0.099
# 0.1
# 0.101
# 0.102
# 0.103
# 0.104
# 0.105
# 0.106
# 0.107
# 0.108
# 0.109
# 0.11
# 0.111
# 0.112
# 0.113
# 0.114
# 0.115
# 0.116
# 0.117
# 0.118
# 0.119
# 0.12
# 0.121
# 0.122
# 0.123
# 0.124
# 0.125
# 0.126
# 0.127
# 0.128
# 0.129
# 0.13
# 0.131
# 0.132
# 0.133
# 0.134
# 0.135
# 0.136
# 0.137
# 0.138
# 0.139
# 0.14
# 0.141
# 0.142
# 0.143
# 0.144
# 0.145
# 0.146
# 0.147
# 0.148
# 0.149
# 0.15
# 0.151
# 0.152
# 0.153
# 0.154
# 0.155
# 0.156
# 0.157
# 0.158
# 0.159
# 0.16
# 0.161
# 0.162
# 0.163
# 0.164
# 0.165
# 0.166
# 0.167
# 0.168
# 0.169
# 0.17
# 0.171
# 0.172
# 0.173
# 0.174
# 0.175
# 0.176
# 0.177
# 0.178
# 0.179
# 0.18
# 0.181
# 0.182
# 0.183
# 0.184
# 0.185
# 0.186
# 0.187
# 0.188
# 0.189
# 0.19
# 0.191
# 0.192
# 0.193
# 0.194
# 0.195
# 0.196
# 0.197
# 0.198
# 0.199
# 0.2
# 0.201
# 0.202
# 0.203
# 0.204
# 0.205
# 0.206
# 0.207
# 0.208
# 0.209
# 0.21
# 0.211
# 0.212
# 0.213
# 0.214
# 0.215
# 0.216
# 0.217
# 0.218
# 0.219
# 0.22
# 0.221
# 0.222
# 0.223
# 0.224
# 0.225
# 0.226
# 0.227
# 0.228
# 0.229
# 0.23
# 0.231
# 0.232
# 0.233
# 0.234
# 0.235
# 0.236
# 0.237
# 0.238
# 0.239
# 0.24
# 0.241
# 0.242
# 0.243
# 0.244
# 0.245
# 0.246
# 0.247
# 0.248
# 0.249
# 0.25
# 0.251
# 0.252
# 0.253
# 0.254
# 0.255
# 0.256
# 0.257
# 0.258
# 0.259
# 0.26
# 0.261
# 0.262
# 0.263
# 0.264
# 0.265
# 0.266
# 0.267
# 0.268
# 0.269
# 0.27
# 0.271
# 0.272
# 0.273
# 0.274
# 0.275
# 0.276
# 0.277
# 0.278
# 0.279
# 0.28
# 0.281
# 0.282
# 0.283
# 0.284
# 0.285
# 0.286
# 0.287
# 0.288
# 0.289
# 0.29
# 0.291
# 0.292
# 0.293
# 0.294
# 0.295
# 0.296
# 0.297
# 0.298
# 0.299
# 0.3
# 0.301
# 0.302
# 0.303
# 0.304
# 0.305
# 0.306
# 0.307
# 0.308
# 0.309
# 0.31
# 0.311
# 0.312
# 0.313
# 0.314
# 0.315
# 0.316
# 0.317
# 0.318
# 0.319
# 0.32
# 0.321
# 0.322
# 0.323
# 0.324
# 0.325
# 0.326
# 0.327
# 0.328
# 0.329
# 0.33
# 0.331
# 0.332
# 0.333
# 0.334
# 0.335
# 0.336
# 0.337
# 0.338
# 0.339
# 0.34
# 0.341
# 0.342
# 0.343
# 0.344
# 0.345
# 0.346
# 0.347
# 0.348
# 0.349
# 0.35
# 0.351
# 0.352
# 0.353
# 0.354
# 0.355
# 0.356
# 0.357
# 0.358
# 0.359
# 0.36
# 0.361
# 0.362
# 0.363
# 0.364
# 0.365
# 0.366
# 0.367
# 0.368
# 0.369
# 0.37
# 0.371
# 0.372
# 0.373
# 0.374
# 0.375
# 0.376
# 0.377
# 0.378
# 0.379
# 0.38
# 0.381
# 0.382
# 0.383
# 0.384
# 0.385
# 0.386
# 0.387
# 0.388
# 0.389
# 0.39
# 0.391
# 0.392
# 0.393
# 0.394
# 0.395
# 0.396
# 0.397
# 0.398
# 0.399
# 0.4
# 0.401
# 0.402
# 0.403
# 0.404
# 0.405
# 0.406
# 0.407
# 0.408
# 0.409
# 0.41
# 0.411
# 0.412
# 0.413
# 0.414
# 0.415
# 0.416
# 0.417
# 0.418
# 0.419
# 0.42
# 0.421
# 0.422
# 0.423
# 0.424
# 0.425
# 0.426
# 0.427
# 0.428
# 0.429
# 0.43
# 0.431
# 0.432
# 0.433
# 0.434
# 0.435
# 0.436
# 0.437
# 0.438
# 0.439
# 0.44
# 0.441
# 0.442
# 0.443
# 0.444
# 0.445
# 0.446
# 0.447
# 0.448
# 0.449
# 0.45
# 0.451
# 0.452
# 0.453
# 0.454
# 0.455
# 0.456
# 0.457
# 0.458
# 0.459
# 0.46
# 0.461
# 0.462
# 0.463
# 0.464
# 0.465
# 0.466
# 0.467
# 0.468
# 0.469
# 0.47
# 0.471
# 0.472
# 0.473
# 0.474
# 0.475
# 0.476
# 0.477
# 0.478
# 0.479
# 0.48
# 0.481
# 0.482
# 0.483
# 0.484
# 0.485
# 0.486
# 0.487
# 0.488
# 0.489
# 0.49
# 0.491
# 0.492
# 0.493
# 0.494
# 0.495
# 0.496
# 0.497
# 0.498
# 0.499
# 0.5
# 0.501
# 0.502
# 0.503
# 0.504
# 0.505
# 0.506
# 0.507
# 0.508
# 0.509
# 0.51
# 0.511
# 0.512
# 0.513
# 0.514
# 0.515
# 0.516
# 0.517
# 0.518
# 0.519
# 0.52
# 0.521
# 0.522
# 0.523
# 0.524
# 0.525
# 0.526
# 0.527
# 0.528
# 0.529
# 0.53
# 0.531
# 0.532
# 0.533
# 0.534
# 0.535
# 0.536
# 0.537
# 0.538
# 0.539
# 0.54
# 0.541
# 0.542
# 0.543
# 0.544
# 0.545
# 0.546
# 0.547
# 0.548
# 0.549
# 0.55
# 0.551
# 0.552
# 0.553
# 0.554
# 0.555
# 0.556
# 0.557
# 0.558
# 0.559
# 0.56
# 0.561
# 0.562
# 0.563
# 0.564
# 0.565
# 0.566
# 0.567
# 0.568
# 0.569
# 0.57
# 0.571
# 0.572
# 0.573
# 0.574
# 0.575
# 0.576
# 0.577
# 0.578
# 0.579
# 0.58
# 0.581
# 0.582
# 0.583
# 0.584
# 0.585
# 0.586
# 0.587
# 0.588
# 0.589
# 0.59
# 0.591
# 0.592
# 0.593
# 0.594
# 0.595
# 0.596
# 0.597
# 0.598
# 0.599
# 0.6
# 0.601
# 0.602
# 0.603
# 0.604
# 0.605
# 0.606
# 0.607
# 0.608
# 0.609
# 0.61
# 0.611
# 0.612
# 0.613
# 0.614
# 0.615
# 0.616
# 0.617
# 0.618
# 0.619
# 0.62
# 0.621
# 0.622
# 0.623
# 0.624
# 0.625
# 0.626
# 0.627
# 0.628
# 0.629
# 0.63
# 0.631
# 0.632
# 0.633
# 0.634
# 0.635
# 0.636
# 0.637
# 0.638
# 0.639
# 0.64
# 0.641
# 0.642
# 0.643
# 0.644
# 0.645
# 0.646
# 0.647
# 0.648
# 0.649
# 0.65
# 0.651
# 0.652
# 0.653
# 0.654
# 0.655
# 0.656
# 0.657
# 0.658
# 0.659
# 0.66
# 0.661
# 0.662
# 0.663
# 0.664
# 0.665
# 0.666
# 0.667
# 0.668
# 0.669
# 0.67
# 0.671
# 0.672
# 0.673
# 0.674
# 0.675
# 0.676
# 0.677
# 0.678
# 0.679
# 0.68
# 0.681
# 0.682
# 0.683
# 0.684
# 0.685
# 0.686
# 0.687
# 0.688
# 0.689
# 0.69
# 0.691
# 0.692
# 0.693
# 0.694
# 0.695
# 0.696
# 0.697
# 0.698
# 0.699
# 0.7
# 0.701
# 0.702
# 0.703
# 0.704
# 0.705
# 0.706
# 0.707
# 0.708
# 0.709
# 0.71
# 0.711
# 0.712
# 0.713
# 0.714
# 0.715
# 0.716
# 0.717
# 0.718
# 0.719
# 0.72
# 0.721
# 0.722
# 0.723
# 0.724
# 0.725
# 0.726
# 0.727
# 0.728
# 0.729
# 0.73
# 0.731
# 0.732
# 0.733
# 0.734
# 0.735
# 0.736
# 0.737
# 0.738
# 0.739
# 0.74
# 0.741
# 0.742
# 0.743
# 0.744
# 0.745
# 0.746
# 0.747
# 0.748
# 0.749
# 0.75
# 0.751
# 0.752
# 0.753
# 0.754
# 0.755
# 0.756
# 0.757
# 0.758
# 0.759
# 0.76
# 0.761
# 0.762
# 0.763
# 0.764
# 0.765
# 0.766
# 0.767
# 0.768
# 0.769
# 0.77
# 0.771
# 0.772
# 0.773
# 0.774
# 0.775
# 0.776
# 0.777
# 0.778
# 0.779
# 0.78
# 0.781
# 0.782
# 0.783
# 0.784
# 0.785
# 0.786
# 0.787
# 0.788
# 0.789
# 0.79
# 0.791
# 0.792
# 0.793
# 0.794
# 0.795
# 0.796
# 0.797
# 0.798
# 0.799
# 0.8
# 0.801
# 0.802
# 0.803
# 0.804
# 0.805
# 0.806
# 0.807
# 0.808
# 0.809
# 0.81
# 0.811
# 0.812
# 0.813
# 0.814
# 0.815
# 0.816
# 0.817
# 0.818
# 0.819
# 0.82
# 0.821
# 0.822
# 0.823
# 0.824
# 0.825
# 0.826
# 0.827
# 0.828
# 0.829
# 0.83
# 0.831
# 0.832
# 0.833
# 0.834
# 0.835
# 0.836
# 0.837
# 0.838
# 0.839
# 0.84
# 0.841
# 0.842
# 0.843
# 0.844
# 0.845
# 0.846
# 0.847
# 0.848
# 0.849
# 0.85
# 0.851
# 0.852
# 0.853
# 0.854
# 0.855
# 0.856
# 0.857
# 0.858
# 0.859
# 0.86
# 0.861
# 0.862
# 0.863
# 0.864
# 0.865
# 0.866
# 0.867
# 0.868
# 0.869
# 0.87
# 0.871
# 0.872
# 0.873
# 0.874
# 0.875
# 0.876
# 0.877
# 0.878
# 0.879
# 0.88
# 0.881
# 0.882
# 0.883
# 0.884
# 0.885
# 0.886
# 0.887
# 0.888
# 0.889
# 0.89
# 0.891
# 0.892
# 0.893
# 0.894
# 0.895
# 0.896
# 0.897
# 0.898
# 0.899
# 0.9
# 0.901
# 0.902
# 0.903
# 0.904
# 0.905
# 0.906
# 0.907
# 0.908
# 0.909
# 0.91
# 0.911
# 0.912
# 0.913
# 0.914
# 0.915
# 0.916
# 0.917
# 0.918
# 0.919
# 0.92
# 0.921
# 0.922
# 0.923
# 0.924
# 0.925
# 0.926
# 0.927
# 0.928
# 0.929
# 0.93
# 0.931
# 0.932
# 0.933
# 0.934
# 0.935
# 0.936
# 0.937
# 0.938
# 0.939
# 0.94
# 0.941
# 0.942
# 0.943
# 0.944
# 0.945
# 0.946
# 0.947
# 0.948
# 0.949
# 0.95
# 0.951
# 0.952
# 0.953
# 0.954
# 0.955
# 0.956
# 0.957
# 0.958
# 0.959
# 0.96
# 0.961
# 0.962
# 0.963
# 0.964
# 0.965
# 0.966
# 0.967
# 0.968
# 0.969
# 0.97
# 0.971
# 0.972
# 0.973
# 0.974
# 0.975
# 0.976
# 0.977
# 0.978
# 0.979
# 0.98
# 0.981
# 0.982
# 0.983
# 0.984
# 0.985
# 0.986
# 0.987
# 0.988
# 0.989
# 0.99
# 0.991
# 0.992
# 0.993
# 0.994
# 0.995
# 0.996
# 0.997
# 0.998
# 0.999
# 1.0
# NPFocus calibrated threshold for variance change detection: 121.33251221715204
# Large-scale comparison (1000 series, variance change 1→3):
# Bernoulli detector:
#   Average detection delay: 11.90 samples
#   Average runtime: 45.976 ms
#   False alarm rate: 0.0500
#   Missed detections: 0
#
# NPFocus detector:
#   Average detection delay: 17.31 samples
#   Average runtime: 1339.880 ms
#   False alarm rate: 0.0300
#   Missed detections: 0
#
# Speedup: NPFocus is 29.1x slower than Bernoulli detector

# %% [markdown]
# # Old stuff:

# %%
@nb.njit
def h(y):
    return y


@nb.njit
def f(sum_pre_j, sum_post_j, g, t):
    res = math.sqrt(1.0 * g / (t * (t - g))) * sum_pre_j
    res = res - math.sqrt(1.0 * (t - g) / t / g) * sum_post_j
    return np.sum(res * res)


@nb.njit
def penalty(g, t, p):
    logg = fastlog(t / 0.05)
    rr = math.sqrt(p * logg) + logg

    return rr

# %%
N = 1000
K = 1000
p = 10
null_dist = np.random.normal
null_args = (0, 1)  # mean=0, std=1
sample = mc_max_statistics(
    N=N,
    K=K,
    p=p,
    h=h,
    f=f,
    penalty=penalty,
    null_dist=null_dist,
    penalty_constant=0.0,
    null_args=null_args,
    null_kwargs=None,
    auxiliary_data=None,
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 6
#       4 null_dist = np.random.normal
#       5 null_args = (0, 1)  # mean=0, std=1
# ----> 6 sample = mc_max_statistics(
#       7     N=N,
#       8     K=K,
#       9     p=p,
#      10     h=h,
#      11     f=f,
#      12     penalty=penalty,
#      13     null_dist=null_dist,
#      14     penalty_constant=0.0,
#      15     null_args=null_args,
#      16     null_kwargs=None,
#      17     auxiliary_data=None,
#      18 )
#
# TypeError: mc_max_statistics() got an unexpected keyword argument 'null_args'

# %%
critical_value = np.percentile(sample, 95)
print(f"Critical value at 95%: {critical_value}")

# %%
xs = np.random.normal(0, 1, (N, p))
xs[(N // 2) :] += 0.2  # Introduce a change point at iteration 8000

state = init_state(p, h, f, penalty, critical_value)
for i in range(N):
    x_new = xs[i]
    update(x_new, state)
    if state["alarm"]:
        print(
            f"Alarm triggered at iteration {i+1} with maxx = {state['maxx']} at position {state['maxpos']}"
        )
        break

# %% [markdown]
# ### Multivariate change in mean or covariance

# %%
@nb.njit
def h_mean_cov(y: np.ndarray) -> np.ndarray:
    p = y.shape[0]
    yy = np.outer(y, y)
    out = np.empty((p + 1, p), dtype=y.dtype)
    out[0] = y
    out[1:] = yy

    return out


@nb.njit
def f_mean_cov(sum_pre_j, sum_post_j, g, t):
    """
    GLR-type statistic for a change in both mean and covariance
    in multivariate Gaussian data.

    sum_pre_j: sum of h(y) over segment 1  (shape (p+1, p))
    sum_post_j: sum of h(y) over segment 2 (shape (p+1, p))
    g: candidate change-point (segment 1 length)
    t: total sample size
    """
    n1 = t - g
    n2 = g

    p = sum_pre_j.shape[0]  # dimension of data
    if n1 <= p or n2 <= p:
        return 0.0

    totalsum = sum_pre_j + sum_post_j
    sum_pre_j_id = sum_pre_j[0]
    sum_post_j_id = sum_post_j[0]
    totalsum_id = totalsum[0]

    sum_pre_j_cov = sum_pre_j[1:]
    sum_post_j_cov = sum_post_j[1:]
    totalsum_cov = totalsum[1:]

    Sigma_tot = (totalsum_cov - np.outer(totalsum_id, totalsum_id) / t) / t
    Sigma_pre_j = (sum_pre_j_cov - np.outer(sum_pre_j_id, sum_pre_j_id) / n1) / n1
    Sigma_post_j = (sum_post_j_cov - np.outer(sum_post_j_id, sum_post_j_id) / n2) / n2

    # GLR statistic: t * log|Sigma| - g* log|Sigma1| - (t-g) * log|Sigma2|
    # Use slogdet for numerical stability
    sign0, logdet0 = np.linalg.slogdet(Sigma_tot)
    sign1, logdet1 = np.linalg.slogdet(Sigma_pre_j)
    sign2, logdet2 = np.linalg.slogdet(Sigma_post_j)

    if False:
        # If any covariance is singular (sign <= 0), treat statistic as 0
        if sign0 <= 0 or sign1 <= 0 or sign2 <= 0:
            if sign0 <= 0:
                print("Sigma_tot is singular or not positive definite")
            if sign1 <= 0:
                print("Sigma_pre_j is singular or not positive definite")
            if sign2 <= 0:
                print("Sigma_post_j is singular or not positive definite")
            return 0.0

    LR = t * logdet0 - n1 * logdet1 - n2 * logdet2
    df = p + (p * (p + 1)) // 2  # Number of parameters in mean+covariance

    return LR - df


@nb.njit
def penalty_mean_cov(g, t, p):
    df = (p * (p + 1)) // 2 + p
    logg = fastlog(t / 0.05)
    rr = math.sqrt(df * logg) + logg

    return rr

# %%
p = 5
S1 = np.zeros((p + 1, p))
S2 = np.zeros((p + 1, p))

T1 = np.zeros((p + 1, p))
T2 = np.zeros((p + 1, p))

NN = 100
for i in range(NN):
    y = np.random.normal(0, 1, p)
    h_y = h_mean_cov(y)
    S1 += h_y
    hy = h_mean_cov(y / 2)
    T1 += hy

    y = np.random.normal(0, 1, p)
    h_y = h_mean_cov(y)
    S2 += h_y
    hy = h_mean_cov(y / 2)
    T2 += hy


r1 = f_mean_cov(S1, S2, 50, 100)
r2 = f_mean_cov(T1, T2, 50, 100)
print(r1)
print(r2)

# %%
N = 1000
K = 1000
p = 10
null_dist = np.random.normal
null_args = (0, 1)  # mean=0, std=1
sample = mc_max_statistics(
    N=N,
    K=K,
    p=p,
    h=h_mean_cov,
    f=f_mean_cov,
    penalty=penalty_mean_cov,
    null_dist=null_dist,
    penalty_constant=0.0,
    null_args=null_args,
    null_kwargs=None,
    auxiliary_data=None,
)

# %%
critical_value = np.percentile(sample, 95)
print(f"Critical value at 95%: {critical_value}")

# %%
xs = np.random.normal(0, 1, (N, p))
xs[(N // 2) :] += 0.4

state = init_state(p, h_mean_cov, f_mean_cov, penalty_mean_cov, critical_value)
for i in range(N):
    x_new = xs[i]
    update(x_new, state)
    if state["alarm"]:
        print(
            f"Alarm triggered at iteration {i+1} with maxx = {state['maxx']} at position {state['maxpos']}"
        )
        break

# %%
xs = np.zeros((N, p))
xs[: (N // 2)] = np.random.normal(0, 1, (N // 2, p))
xs[(N // 2) :] = np.random.normal(0, 0.5, (N // 2, p))  # Introduce a changepoint


state = init_state(p, h_mean_cov, f_mean_cov, penalty_mean_cov, critical_value)
for i in range(N):
    x_new = xs[i]
    update(x_new, state)
    if state["alarm"]:
        print(
            f"Alarm triggered at iteration {i+1} with maxx = {state['maxx']} at position {state['maxpos']}"
        )
        break

# %%
state

# %% [markdown]
# ### General likelihood ratio test using Numba, requiring gradients

# %%
## Specific examples are for Bernoulli with natural param theta = log(p/(1-p)) and A(theta) = log(1 + exp(theta))


from matplotlib.pylab import inf


@nb.njit
def h(y):
    return y


@nb.njit
def A_func(theta):
    return np.log(1.0 + np.exp(theta)).sum()


@nb.njit
def grad_A(theta):
    ee = np.exp(theta)
    return ee / (1.0 + ee)


@nb.njit
def hess_A(theta):
    H = np.zeros((1, 1), dtype=np.float64)
    ee = np.exp(theta)
    H[0, 0] = (ee / ((1.0 + ee) ** 2)).sum()
    return H


@nb.njit
def penalty(g, t, p):
    logg = fastlog(t / 0.05)
    rr = math.sqrt(p * logg) + logg

    return rr


## The below should be general


@nb.njit
def logLik(theta, S, n):
    # S is cumulative sum!
    # n is total sample size

    # if S is numerically zero or n, we return zero:
    if np.all(np.abs(S) < 1e-10) or np.all(np.abs(S - n) < 1e-10):
        return 0.0
    A_theta = A_func(theta)
    return np.dot(theta, S) - n * A_theta


@nb.njit
def newton_mle(
    S, n, theta_init, A_func, grad_A, hess_A, logLik, tol=1e-12, max_iter=1000
):
    """
    Maximize logLik(theta; S, n) = theta @ S - n * A_func(theta)
    over theta ∈ R^v using safeguarded Newton.

    Inputs
    ------
    S : 1D array (v,)
        Sum of sufficient statistics.
    n : int
        Number of observations.
    theta_init : 1D array (v,)
        Starting point (e.g. previous MLE or some fixed value).
    tol : float
        Stop when ||grad||_inf < tol.
    max_iter : int
        Hard cap on number of iterations.

    Returns
    -------
    theta_hat : 1D array (v,)
    converged : boolean
    """

    if (np.abs(S) < 1e-10).all():
        return np.array([-np.inf]), True

    if (np.abs(S - n) < 1e-10).all():
        return np.array([np.inf]), True

    theta = theta_init
    v = theta.shape[0]

    # Small ridge for numerical stability of Hessian
    ridge = 1e-8

    # current log-likelihood
    ll_old = logLik(theta, S, n)

    for it in range(max_iter):
        # Gradient of log-likelihood: S - n * grad_A(theta)
        gA = grad_A(theta)  # shape (v,)
        grad = S - n * gA  # shape (v,)

        # Check convergence: ||grad||_inf < tol
        max_abs_grad = 0.0
        for i in range(v):
            val = grad[i]
            if val < 0.0:
                val = -val
            if val > max_abs_grad:
                max_abs_grad = val
        if max_abs_grad < tol:
            return theta, True

        # Hessian of log-likelihood: H = -n * hess_A(theta)
        HA = hess_A(theta)  # shape (v, v)
        H = np.empty_like(HA)
        for i in range(v):
            for j in range(v):
                H[i, j] = -n * HA[i, j]
        # Add a small ridge to diagonal: H ← H − ridge * I
        # (H is negative semidefinite; we move it slightly more negative
        # to make it better-conditioned)
        for i in range(v):
            H[i, i] = H[i, i] - ridge

        # Solve H * step = grad
        # (instead of explicitly inverting H)
        try:
            step = np.linalg.solve(H, grad)
        except Exception:
            # If solve fails for some reason, abort
            return theta, False

        # Safeguard: start with full Newton step, shrink if ll decreases
        step_scale = 1.0
        theta_new = theta.copy()
        ll_new = ll_old

        # At most a few shrink steps (hard-coded; no user tuning)
        for _ in range(6):
            for i in range(v):
                theta_new[i] = theta[i] + step_scale * step[i]

            ll_candidate = logLik(theta_new, S, n)

            if np.isfinite(ll_candidate) and ll_candidate >= ll_old:
                ll_new = ll_candidate
                break  # accept this step
            else:
                step_scale *= 0.5  # shrink and try again

        # Update
        theta = theta_new
        ll_old = ll_new

    # If we fall out of the loop, we hit max_iter
    return theta, False


@nb.njit
def f(sum_pre_j, sum_post_j, g, t):
    print("###################")
    print("Iter ", t, " g ", g)
    theta_init = np.zeros(sum_pre_j.shape[0], dtype=np.float64)
    theta0, converged = newton_mle(
        sum_pre_j + sum_post_j, t, theta_init, A_func, grad_A, hess_A, logLik
    )
    print("theta0 ", theta0)
    print("converged = ", converged)
    theta1, converged1 = newton_mle(
        sum_pre_j, t - g, theta0, A_func, grad_A, hess_A, logLik
    )
    theta2, converged2 = newton_mle(
        sum_post_j, g, theta0, A_func, grad_A, hess_A, logLik
    )
    print("theta1 ", theta1)
    print("converged1 = ", converged1)
    print("theta2 ", theta2)
    print("converged2 = ", converged2)
    ll0 = logLik(theta0, sum_pre_j + sum_post_j, t)
    ll1 = logLik(theta1, sum_pre_j, t - g)
    ll2 = logLik(theta2, sum_post_j, g)
    print("ll0 = ", ll0)
    print("ll1 = ", ll1)
    print("ll2 = ", ll2)
    print("LR = ", ll1 + ll2 - ll0)
    return ll1 + ll2 - ll0

# %%
p = 1
penalty_constant = 3.0
N = 10
xs = np.zeros(N)
p0 = 0.1
p1 = 0.8
xs[: (N // 2)] = np.random.binomial(n=1, p=p0, size=N // 2)
xs[(N // 2) :] = np.random.binomial(n=1, p=p1, size=N // 2)

xs[:10]

# %%
state = init_state(p, h, f, penalty, penalty_constant)

for i in range(N):
    x_new = xs[i]
    update(x_new, state)
    if state["alarm"]:
        print(
            f"Alarm triggered at iteration {i+1} with maxx = {state['maxx']} at position {state['maxpos']}"
        )
        break

# %% [markdown]
# ### General likelihood ratio test (non-Numba) using autograd. Fully automatic. sucks

# %%
import autograd.numpy as anp
from autograd import grad
from scipy.optimize import minimize

## Currently, the binomial:


def h(y):
    return y


def A_func(theta):
    ## theta is natural parameter, for bernoulli, A(theta) = log(1 + exp(theta))
    ## and theta = log(p/(1-p)) where p is the Bernoulli paramete
    ret = anp.log(1.0 + anp.exp(theta))
    return ret


def logLik(theta, S, n):
    # S is cumulative sum!
    A_theta = A_func(theta)
    return anp.dot(theta, S) - n * A_theta


theta_init = anp.zeros(1)
df = 1
p = 1


def f(sum_pre_j, sum_post_j, g, t):
    # compute MLEs
    # Overall MLE:
    def objective(theta_flat):
        return -logLik(
            theta_flat, sum_pre_j + sum_post_j, t
        )  # negative for minimization

    def objective_grad(theta_flat):
        theta = theta_flat
        gg = grad(logLik, argnum=0)(theta, sum_pre_j + sum_post_j, t)  # shape (v,)
        return -gg  # because we minimize the negative

    res = minimize(
        objective,
        x0=theta_init,
        jac=objective_grad,
        method="L-BFGS-B",
        options={"maxiter": 200, "disp": False},
    )
    theta0 = res.x

    def objective(theta_flat):
        return -logLik(theta_flat, sum_pre_j, t - g)  # negative for minimization

    def objective_grad(theta_flat):
        theta = theta_flat
        gg = grad(logLik, argnum=0)(theta, sum_pre_j, t - g)  # shape (v,)
        return -gg  # because we minimize the negative

    res = minimize(
        objective,
        x0=theta0,
        jac=objective_grad,
        method="L-BFGS-B",
        options={"maxiter": 200, "disp": False},
    )
    theta1 = res.x

    def objective(theta_flat):
        return -logLik(theta_flat, sum_post_j, g)  # negative for minimization

    def objective_grad(theta_flat):
        theta = theta_flat
        gg = grad(logLik, argnum=0)(theta, sum_post_j, g)  # shape (v,)
        return -gg  # because we minimize the negative

    res = minimize(
        objective,
        x0=theta0,
        jac=objective_grad,
        method="L-BFGS-B",
        options={"maxiter": 200, "disp": False},
    )
    theta2 = res.x

    ret = (
        logLik(theta0, sum_pre_j + sum_post_j, t)
        + logLik(theta1, sum_pre_j, t - g)
        + logLik(theta2, sum_post_j, g)
        - df
    )
    print("ret = ", ret)
    return ret


@nb.njit
def penalty(g, t, p):
    logg = fastlog(t / 0.05)
    rr = math.sqrt(p * logg) + logg

    return rr

# %%
p = 1
penalty_constant = 3.0
N = 100
xs = np.zeros(N)
p0 = 0.5
p1 = 0.8
xs[: (N // 2)] = np.random.binomial(n=1, p=p0, size=N // 2)
xs[(N // 2) :] = np.random.binomial(n=1, p=p1, size=N // 2)

state = init_state(p, h, f, penalty, penalty_constant)
for i in range(N):
    x_new = xs[i]
    update(x_new, state)
    if state["alarm"]:
        print(
            f"Alarm triggered at iteration {i+1} with maxx = {state['maxx']} at position {state['maxpos']}"
        )
        break

# %%
state
